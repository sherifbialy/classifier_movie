# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# # With GPU

# %%
import os
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import matplotlib.pyplot as plt


np.random.seed(42)
tf.random.set_seed(42)


k = 4


data_dir = "/content/drive/MyDrive/Data"
subdirs = [os.path.join(data_dir, subdir) for subdir in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, subdir))]


class_labels = sorted([subdir.split('/')[-1] for subdir in subdirs])


num_samples = sum([len(os.listdir(subdir)) for subdir in subdirs])


indices = np.arange(num_samples)


accuracies = []
confusion_matrices = []
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)


def create_cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(240, 360, 3), padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(32, (5, 5), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(16, (7, 7), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(128, activation='sigmoid'))
    model.add(Dense(len(class_labels), activation='softmax'))

    return model


kf = KFold(n_splits=k, shuffle=True, random_state=42)

accuracy_history = []
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(data_dir,
                                                    target_size=(240, 360),
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    subset='training',
                                                    seed=42,
                                                    classes=class_labels)

validation_generator = train_datagen.flow_from_directory(data_dir,
                                                        target_size=(240, 360),
                                                        batch_size=32,
                                                        class_mode='categorical',
                                                        subset='validation',
                                                        seed=42,
                                                        classes=class_labels)

test_generator = test_datagen.flow_from_directory(data_dir,
                                                  target_size=(240, 360),
                                                  batch_size=32,
                                                  class_mode='categorical',
                                                  seed=42,
                                                  shuffle=False,
                                                  classes=class_labels)
# Out:
# Found 10535 images belonging to 6 classes.
# Found 2630 images belonging to 6 classes.
# Found 13165 images belonging to 6 classes.

# %%
import os
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import matplotlib.pyplot as plt


np.random.seed(42)
tf.random.set_seed(42)

k = 4


data_dir = "/content/drive/MyDrive/Data"
subdirs = [os.path.join(data_dir, subdir) for subdir in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, subdir))]

class_labels = sorted([subdir.split('/')[-1] for subdir in subdirs])


num_samples = sum([len(os.listdir(subdir)) for subdir in subdirs])


indices = np.arange(num_samples)


accuracies = []
confusion_matrices = []


gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)


def create_cnn_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(240, 360, 3), padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(32, (5, 5), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(16, (7, 7), activation='relu', padding='valid'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(128, activation='sigmoid'))
    model.add(Dense(len(class_labels), activation='softmax'))

    return model


kf = KFold(n_splits=k, shuffle=True, random_state=42)

accuracy_history = []

for fold, (train_index, test_index) in enumerate(kf.split(indices)):
    train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
    test_datagen = ImageDataGenerator(rescale=1./255)


    train_generator = train_datagen.flow_from_directory(data_dir,
                                                       target_size=(240, 360),
                                                       batch_size=32,
                                                       class_mode='categorical',
                                                       subset='training',
                                                       seed=42,
                                                       classes=class_labels)

    validation_generator = train_datagen.flow_from_directory(data_dir,
                                                            target_size=(240, 360),
                                                            batch_size=32,
                                                            class_mode='categorical',
                                                            subset='validation',
                                                            seed=42,
                                                            classes=class_labels)

    test_generator = test_datagen.flow_from_directory(data_dir,
                                                     target_size=(240, 360),
                                                     batch_size=32,
                                                     class_mode='categorical',
                                                     seed=42,
                                                     shuffle=False,
                                                     classes=class_labels)


    model = create_cnn_model()

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])


    history = model.fit(train_generator, validation_data=validation_generator, epochs=10)
    accuracy_history.append(history.history['accuracy'])


    _, test_acc = model.evaluate(test_generator)
    accuracies.append(test_acc)

    y_true = test_generator.classes
    y_pred = model.predict(test_generator)
    y_pred = np.argmax(y_pred, axis=1)


    confusion_matrices.append(confusion_matrix(y_true, y_pred))

    model.save(f'model_fold{fold}.h5')

    print(f"Validation accuracy for fold {fold}: {test_acc:.4f}")
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# Found 10535 images belonging to 6 classes.
# Found 2630 images belonging to 6 classes.
# Found 13165 images belonging to 6 classes.
# Epoch 1/10
# 330/330 [==============================] - 3589s 11s/step - loss: 0.9303 - accuracy: 0.6477 - val_loss: 1.6177 - val_accuracy: 0.3046
# Epoch 2/10
# 330/330 [==============================] - 123s 372ms/step - loss: 0.4521 - accuracy: 0.8302 - val_loss: 1.4661 - val_accuracy: 0.4319
# Epoch 3/10
# 330/330 [==============================] - 126s 381ms/step - loss: 0.2972 - accuracy: 0.9031 - val_loss: 1.8640 - val_accuracy: 0.3525
# Epoch 4/10
# 330/330 [==============================] - 125s 379ms/step - loss: 0.2169 - accuracy: 0.9295 - val_loss: 1.8810 - val_accuracy: 0.4654
# Epoch 5/10
# 330/330 [==============================] - 147s 444ms/step - loss: 0.1621 - accuracy: 0.9494 - val_loss: 2.1249 - val_accuracy: 0.4414
# Epoch 6/10
# 330/330 [==============================] - 128s 387ms/step - loss: 0.1404 - accuracy: 0.9583 - val_loss: 2.1409 - val_accuracy: 0.4555
# Epoch 7/10
# 330/330 [==============================] - 126s 381ms/step - loss: 0.1021 - accuracy: 0.9692 - val_loss: 2.0260 - val_accuracy: 0.4582
# Epoch 8/10
# 330/330 [==============================] - 128s 388ms/step - loss: 0.0852 - accuracy: 0.9748 - val_loss: 2.0460 - val_accuracy: 0.4916
# Epoch 9/10
# 330/330 [==============================] - 124s 377ms/step - loss: 0.0751 - accuracy: 0.9782 - val_loss: 2.0191 - val_accuracy: 0.4582
# Epoch 10/10
# 330/330 [==============================] - 124s 377ms/step - loss: 0.0555 - accuracy: 0.9849 - val_loss: 2.6663 - val_accuracy: 0.4730
# 412/412 [==============================] - 120s 291ms/step - loss: 0.5828 - accuracy: 0.8773
# 412/412 [==============================] - 118s 286ms/step
# Validation accuracy for fold 1: 0.8773
# Found 10535 images belonging to 6 classes.
# Found 2630 images belonging to 6 classes.
# Found 13165 images belonging to 6 classes.
# Epoch 1/10
# 330/330 [==============================] - 128s 382ms/step - loss: 1.0349 - accuracy: 0.6088 - val_loss: 1.4861 - val_accuracy: 0.3574
# Epoch 2/10
# 330/330 [==============================] - 124s 376ms/step - loss: 0.4716 - accuracy: 0.8241 - val_loss: 1.5428 - val_accuracy: 0.4255
# Epoch 3/10
# 330/330 [==============================] - 128s 388ms/step - loss: 0.2824 - accuracy: 0.9092 - val_loss: 1.4938 - val_accuracy: 0.4996
# Epoch 4/10
# 330/330 [==============================] - 129s 390ms/step - loss: 0.1990 - accuracy: 0.9363 - val_loss: 1.7322 - val_accuracy: 0.4532
# Epoch 5/10
# 330/330 [==============================] - 143s 435ms/step - loss: 0.1416 - accuracy: 0.9577 - val_loss: 1.6699 - val_accuracy: 0.5414
# Epoch 6/10
# 330/330 [==============================] - 126s 382ms/step - loss: 0.1189 - accuracy: 0.9618 - val_loss: 2.0454 - val_accuracy: 0.5034
# Epoch 7/10
# 330/330 [==============================] - 126s 382ms/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 2.3389 - val_accuracy: 0.4700
# Epoch 8/10
# 330/330 [==============================] - 127s 385ms/step - loss: 0.0795 - accuracy: 0.9750 - val_loss: 2.0830 - val_accuracy: 0.5038
# Epoch 9/10
# 330/330 [==============================] - 126s 383ms/step - loss: 0.0633 - accuracy: 0.9807 - val_loss: 2.2989 - val_accuracy: 0.4958
# Epoch 10/10
# 330/330 [==============================] - 128s 386ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 2.3873 - val_accuracy: 0.4856
# 412/412 [==============================] - 120s 290ms/step - loss: 0.5064 - accuracy: 0.8897
# 412/412 [==============================] - 122s 296ms/step
# Validation accuracy for fold 2: 0.8897
# Found 10535 images belonging to 6 classes.
# Found 2630 images belonging to 6 classes.
# Found 13165 images belonging to 6 classes.
# Epoch 1/10
# 330/330 [==============================] - 126s 371ms/step - loss: 0.8067 - accuracy: 0.6842 - val_loss: 1.4703 - val_accuracy: 0.3692
# Epoch 2/10
# 330/330 [==============================] - 123s 372ms/step - loss: 0.3240 - accuracy: 0.8896 - val_loss: 1.5059 - val_accuracy: 0.4951
# Epoch 3/10
# 330/330 [==============================] - 123s 371ms/step - loss: 0.1998 - accuracy: 0.9374 - val_loss: 1.5580 - val_accuracy: 0.4513
# Epoch 4/10
# 330/330 [==============================] - 127s 384ms/step - loss: 0.1461 - accuracy: 0.9547 - val_loss: 1.9812 - val_accuracy: 0.5426
# Epoch 5/10
# 330/330 [==============================] - 125s 378ms/step - loss: 0.1454 - accuracy: 0.9574 - val_loss: 1.9052 - val_accuracy: 0.5061
# Epoch 6/10
# 330/330 [==============================] - 125s 379ms/step - loss: 0.1221 - accuracy: 0.9630 - val_loss: 1.7126 - val_accuracy: 0.4962
# Epoch 7/10
# 330/330 [==============================] - 124s 375ms/step - loss: 0.1001 - accuracy: 0.9689 - val_loss: 1.9837 - val_accuracy: 0.4939
# Epoch 8/10
# 330/330 [==============================] - 141s 428ms/step - loss: 0.0852 - accuracy: 0.9736 - val_loss: 1.9057 - val_accuracy: 0.4821
# Epoch 9/10
# 330/330 [==============================] - 127s 384ms/step - loss: 0.0716 - accuracy: 0.9787 - val_loss: 1.8878 - val_accuracy: 0.5091
# Epoch 10/10
# 330/330 [==============================] - 124s 376ms/step - loss: 0.0638 - accuracy: 0.9809 - val_loss: 2.4558 - val_accuracy: 0.4392
# 412/412 [==============================] - 117s 283ms/step - loss: 0.5476 - accuracy: 0.8722
# 412/412 [==============================] - 117s 284ms/step
# Validation accuracy for fold 3: 0.8722
# Found 10535 images belonging to 6 classes.
# Found 2630 images belonging to 6 classes.
# Found 13165 images belonging to 6 classes.
# Epoch 1/10
# 330/330 [==============================] - 127s 373ms/step - loss: 0.9409 - accuracy: 0.6407 - val_loss: 1.6168 - val_accuracy: 0.3650
# Epoch 2/10
# 330/330 [==============================] - 123s 373ms/step - loss: 0.5177 - accuracy: 0.8154 - val_loss: 1.4658 - val_accuracy: 0.3677
# Epoch 3/10
# 330/330 [==============================] - 124s 376ms/step - loss: 0.3539 - accuracy: 0.8777 - val_loss: 1.7451 - val_accuracy: 0.3810
# Epoch 4/10
# 330/330 [==============================] - 124s 376ms/step - loss: 0.2687 - accuracy: 0.9067 - val_loss: 2.0020 - val_accuracy: 0.3262
# Epoch 5/10
# 330/330 [==============================] - 123s 372ms/step - loss: 0.2127 - accuracy: 0.9286 - val_loss: 1.9743 - val_accuracy: 0.4243
# Epoch 6/10
# 330/330 [==============================] - 123s 373ms/step - loss: 0.1686 - accuracy: 0.9464 - val_loss: 2.2219 - val_accuracy: 0.4072
# Epoch 7/10
# 330/330 [==============================] - 125s 379ms/step - loss: 0.1455 - accuracy: 0.9539 - val_loss: 1.9742 - val_accuracy: 0.5156
# Epoch 8/10
# 330/330 [==============================] - 123s 373ms/step - loss: 0.1080 - accuracy: 0.9658 - val_loss: 2.2369 - val_accuracy: 0.4323
# Epoch 9/10
# 330/330 [==============================] - 140s 423ms/step - loss: 0.0966 - accuracy: 0.9708 - val_loss: 2.1224 - val_accuracy: 0.4221
# Epoch 10/10
# 330/330 [==============================] - 126s 381ms/step - loss: 0.0813 - accuracy: 0.9767 - val_loss: 2.3621 - val_accuracy: 0.4631
# 412/412 [==============================] - 121s 293ms/step - loss: 0.5326 - accuracy: 0.8749
# 412/412 [==============================] - 117s 283ms/step
# Validation accuracy for fold 4: 0.8749

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_58 (Conv2D)          (None, 238, 358, 32)      896
#
#  max_pooling2d_58 (MaxPoolin  (None, 119, 179, 32)     0
#  g2D)
#
#  conv2d_59 (Conv2D)          (None, 117, 177, 64)      18496
#
#  max_pooling2d_59 (MaxPoolin  (None, 58, 88, 64)       0
#  g2D)
#
#  conv2d_60 (Conv2D)          (None, 56, 86, 64)        36928
#
#  max_pooling2d_60 (MaxPoolin  (None, 28, 43, 64)       0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 24, 39, 32)        51232
#
#  max_pooling2d_61 (MaxPoolin  (None, 12, 19, 32)       0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 6, 13, 16)         25104
#
#  max_pooling2d_62 (MaxPoolin  (None, 3, 6, 16)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 288)               0
#
#  dense_24 (Dense)            (None, 128)               36992
#
#  dense_25 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 170,422
# Trainable params: 170,422
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # PLot

# %%
average_accuracy = np.mean(accuracies)
print(f"Average accuracy: {average_accuracy:.4f}")


average_confusion_matrix = np.mean(confusion_matrices, axis=0)
print("Average Confusion Matrix:")
print(average_confusion_matrix)


plt.figure(figsize=(10, 6))
for i, accuracy in enumerate(accuracy_history):
    plt.plot(range(1, len(accuracy)+1), accuracy, label=f'Fold {i+1}')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Iteration')
plt.legend()
plt.show()
# Out:
# Average accuracy: 0.8785
# Average Confusion Matrix:
# [[1.86975e+03 1.40250e+02 3.50000e+00 2.65000e+01 3.30000e+01 0.00000e+00]
#  [2.26250e+02 3.65525e+03 5.30000e+01 7.75000e+00 3.21000e+02 1.57500e+01]
#  [1.10000e+01 7.50000e+00 9.84750e+02 1.47500e+01 1.20000e+01 0.00000e+00]
#  [2.25000e+00 2.50000e-01 9.75000e+00 1.15650e+03 2.50000e-01 0.00000e+00]
#  [4.95000e+01 4.93000e+02 5.00000e+00 3.25000e+00 3.04175e+03 4.50000e+00]
#  [0.00000e+00 1.59000e+02 0.00000e+00 0.00000e+00 0.00000e+00 8.58000e+02]]

# %%
model = tf.keras.models.load_model(f"/content/model_fold2.h5")  # Load the model of the first fold

# %% [markdown]
# # Infrence

# %%
import random


random_test_index = random.randint(0, len(test_generator) - 1)
test_image, _ = test_generator[random_test_index]


classes = ['Dancing', 'Driving', 'Explosion', 'Football', 'Phone', 'Shooting']

prediction_model = model


predicted_labels = prediction_model.predict(test_image)
predicted_labels = np.argmax(predicted_labels, axis=1)
predicted_class_labels = [class_labels[label] for label in predicted_labels]



plt.imshow(test_image[0])
plt.title(f" \n Predicted: {max(predicted_class_labels)}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 7s 7s/step
